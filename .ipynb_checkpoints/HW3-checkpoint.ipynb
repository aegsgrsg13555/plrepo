# %%
#beautifulsoup是python的函式庫模組
import requests
from bs4 import BeautifulSoup

# %%
#將頁面的HTML抓取下來
#印出HTML
r = requests.get("https://www.ptt.cc/bbs/GHIBLI/index.html")
print(r.text)
# Out:
# <!DOCTYPE html>
# <html>
# 	<head>
# 		<meta charset="utf-8">
#
#
# <meta name="viewport" content="width=device-width, initial-scale=1">
#
# <title>看板 GHIBLI 文章列表 - 批踢踢實業坊</title>
#
# <link rel="stylesheet" type="text/css" href="//images.ptt.cc/bbs/v2.27/bbs-common.css">
# <link rel="stylesheet" type="text/css" href="//images.ptt.cc/bbs/v2.27/bbs-base.css" media="screen">
# <link rel="stylesheet" type="text/css" href="//images.ptt.cc/bbs/v2.27/bbs-custom.css">
# <link rel="stylesheet" type="text/css" href="//images.ptt.cc/bbs/v2.27/pushstream.css" media="screen">
# <link rel="stylesheet" type="text/css" href="//images.ptt.cc/bbs/v2.27/bbs-print.css" media="print">
#
#
#
#
# 	</head>
#     <body>
#
# <div id="topbar-container">
# 	<div id="topbar" class="bbs-content">
# 		<a id="logo" href="/bbs/">批踢踢實業坊</a>
# 		<span>&rsaquo;</span>
# 		<a class="board" href="/bbs/GHIBLI/index.html"><span class="board-label">看板 </span>GHIBLI</a>
# 		<a class="right small" href="/about.html">關於我們</a>
# ...

# %%
#將網頁資料以html.parser存取下來
#取HTML標中的<div class="title"></div>中的<a>標籤存入sel
#目的是為了選取網頁裡的文章標題
soup = BeautifulSoup(r.text,"html.parser")
sel = soup.select("div.title a")

# %%
#寫一個迴圈將所爬的印出來
for s in sel:
    print(s["href"], s.text)
# Out:
# /bbs/GHIBLI/M.1658389916.A.5D8.html Fw: [討論] 海潮之聲評價真的高於心之谷嗎？
# /bbs/GHIBLI/M.1658597923.A.0D8.html [討論] 是被詐騙了嗎？吉卜力演奏會
# /bbs/GHIBLI/M.1660198612.A.E18.html [買賣] 風之谷全套漫畫含盒裝
# /bbs/GHIBLI/M.1660555345.A.498.html Fw: [新聞] 日本吉卜力公園11月開！最新實景曝光
# /bbs/GHIBLI/M.1661434847.A.D8E.html [閒聊] 在Netflix看了天空之城的英文版
# /bbs/GHIBLI/M.1665512438.A.6E3.html [問題] 關於神隱少女的一些疑問？
# /bbs/GHIBLI/M.1667565250.A.37A.html Re: [閒聊] 白龍/賑早見琥珀主的原日文漢字
# /bbs/GHIBLI/M.1669641723.A.94E.html [閒聊] 吉卜力同好討論Line群招募
# /bbs/GHIBLI/M.1670915444.A.32C.html [情報] 吉卜力官方釋出的第一張概念海報
# /bbs/GHIBLI/M.1672503065.A.404.html [情報] 2023年吉卜力新年問候
# /bbs/GHIBLI/M.1673748580.A.E86.html [問題] 帶傘陪伴
# /bbs/GHIBLI/M.1674388146.A.866.html 舊 狂美樂團【久石讓的燦爛樂章】交響音樂會
# /bbs/GHIBLI/M.1681723367.A.5E9.html Fw: [情報] 宮崎駿 高畑勲【熊貓家族】發行BD/DVD
# /bbs/GHIBLI/M.1682699407.A.467.html Re: [情報]『心之谷』真人電影版預告
# /bbs/GHIBLI/M.1684466051.A.959.html [情報] 福岡鈴木敏夫與吉卜力展 限定門票版本
# /bbs/GHIBLI/M.1096734107.A.CDD.html 板規
# /bbs/GHIBLI/M.1290081122.A.DCB.html [公告] 關於灌水文章
# ...

# %%
#擷取上一頁的網頁
u = soup.select("div.btn-group.btn-group-paging a")
url = "https://www.ptt.cc"+ u[1]["href"]
url
# Out:
# 'https://www.ptt.cc/bbs/GHIBLI/index152.html'

# %%
#擷取多頁
url = "https://www.ptt.cc/bbs/GHIBLI/index.html"
#往上爬4頁
for i in range(4): 
    r = requests.get(url)
    soup = BeautifulSoup(r.text,"html.parser")
    sel = soup.select("div.title a") #標題
    u = soup.select("div.btn-group.btn-group-paging a") #a標籤
    print ("本頁的URL為"+url)
    url = "https://www.ptt.cc"+ u[1]["href"] #上一頁的網址

    for s in sel: #印出網址跟標題
        print(s["href"],s.text)
# Out:
# 本頁的URL為https://www.ptt.cc/bbs/GHIBLI/index.html
# /bbs/GHIBLI/M.1658389916.A.5D8.html Fw: [討論] 海潮之聲評價真的高於心之谷嗎？
# /bbs/GHIBLI/M.1658597923.A.0D8.html [討論] 是被詐騙了嗎？吉卜力演奏會
# /bbs/GHIBLI/M.1660198612.A.E18.html [買賣] 風之谷全套漫畫含盒裝
# /bbs/GHIBLI/M.1660555345.A.498.html Fw: [新聞] 日本吉卜力公園11月開！最新實景曝光
# /bbs/GHIBLI/M.1661434847.A.D8E.html [閒聊] 在Netflix看了天空之城的英文版
# /bbs/GHIBLI/M.1665512438.A.6E3.html [問題] 關於神隱少女的一些疑問？
# /bbs/GHIBLI/M.1667565250.A.37A.html Re: [閒聊] 白龍/賑早見琥珀主的原日文漢字
# /bbs/GHIBLI/M.1669641723.A.94E.html [閒聊] 吉卜力同好討論Line群招募
# /bbs/GHIBLI/M.1670915444.A.32C.html [情報] 吉卜力官方釋出的第一張概念海報
# /bbs/GHIBLI/M.1672503065.A.404.html [情報] 2023年吉卜力新年問候
# /bbs/GHIBLI/M.1673748580.A.E86.html [問題] 帶傘陪伴
# /bbs/GHIBLI/M.1674388146.A.866.html 舊 狂美樂團【久石讓的燦爛樂章】交響音樂會
# /bbs/GHIBLI/M.1681723367.A.5E9.html Fw: [情報] 宮崎駿 高畑勲【熊貓家族】發行BD/DVD
# /bbs/GHIBLI/M.1682699407.A.467.html Re: [情報]『心之谷』真人電影版預告
# /bbs/GHIBLI/M.1684466051.A.959.html [情報] 福岡鈴木敏夫與吉卜力展 限定門票版本
# /bbs/GHIBLI/M.1096734107.A.CDD.html 板規
# ...

# %%
#利用python爬出圖片
import requests

# %%
#變數名稱為pic
pic = requests.get('https://upload.wikimedia.org/wikipedia/commons/thumb/e/ec/Capybara_%28Hydrochoerus_hydrochaeris%29.JPG/1200px-Capybara_%28Hydrochoerus_hydrochaeris%29.JPG')

# %%
#將其轉為二進制方式
img2 = pic.content
img2
# Out:
# b'\xff\xd8\xff\xe2\x02\x1cICC_PROFILE\x00\x01\x01\x00\x00\x02\x0clcms\x02\x10\x00\x00mntrRGB XYZ \x07\xdc\x00\x01\x00\x19\x00\x03\x00)\x009acspAPPL\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\xf6\xd6\x00\x01\x00\x00\x00\x00\xd3-lcms\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\ndesc\x00\x00\x00\xfc\x00\x00\x00^cprt\x00\x00\x01\\\x00\x00\x00\x0bwtpt\x00\x00\x01h\x00\x00\x00\x14bkpt\x00\x00\x01|\x00\x00\x00\x14rXYZ\x00\x00\x01\x90\x00\x00\x00\x14gXYZ\x00\x00\x01\xa4\x00\x00\x00\x14bXYZ\x00\x00\x01\xb8\x00\x00\x00\x14rTRC\x00\x00\x01\xcc\x00\x00\x00@gTRC\x00\x00\x01\xcc\x00\x00\x00@bTRC\x00\x00\x01\xcc\x00\x00\x00@desc\x00\x00\x00\x00\x00\x00\x00\x03c2\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x
# ...

# %%
pic_out = open('img1.png','wb') #img1.png為預存檔的圖片名稱
pic_out.write(img2) #將get圖片存入img1.png
pic_out.close() #關閉檔案(很重要)否則可能使文件保持打開的時間超過預期.
