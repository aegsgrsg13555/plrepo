# %%
import json
test=open('generated.json',encoding="utf8")
Data=json.load(test)
type(Data)
# Out:
# dict

# %%
Data.items()
# Out:
# dict_items([('result', [{'編號': 1, '村別數': '東門里', '鄰數': 31, '戶數': 1700, '男數': 2750, '女數': 2799, '總人口數': 5549, '出生人數': 6, '死亡人數': 2, '結婚對數': 1, '離婚對數': 0, '遷入人數': 7, '遷出人數': 24}, {'編號': 2, '村別數': '西門里', '鄰數': 42, '戶數': 3492, '男數': 5469, '女數': 5732, '總人口數': 11201, '出生人數': 8, '死亡人數': 4, '結婚對數': 3, '離婚對數': 1, '遷入人數': 23, '遷出人數': 38}, {'編號': 3, '村別數': '南門里', '鄰數': 34, '戶數': 1910, '男數': 2983, '女數': 3091, '總人口數': 6074, '出生人數': 4, '死亡人數': 1, '結婚對數': 2, '離婚對數': 0, '遷入人數': 17, '遷出人數': 20}, {'編號': 4, '村別數': '北門里', '鄰數': 28, '戶數': 1386, '男數': 2308, '女數': 2210, '總人口數': 4518, '出生人數': 2, '死亡人數': 2, '結婚對數': 0, '離婚對數': 0, '遷入人數': 15, '遷出人數': 26}, {'編號': 5, '村別數': '古城里', '鄰數': 25, '戶數': 1396, '男數': 2267, '女數': 2249, '總人口數': 4516, '出生人數': 3, '死亡人數': 1, '結婚對數': 1, '離婚對數': 0, '遷入人數': 12, '遷出人數': 14}, {'編號': 6, '村別數': '金水里', '鄰數': 16, '戶數': 726, '男數': 1259, '女數': 1167, '總人口數': 2426, '出生人數': 5, '死亡人數': 1, '結婚對數': 1, '離婚對數': 0, '遷入人數': 7, '遷出人數': 6}, {'編號': 7, '村別數': '珠沙里', '鄰數': 21, '戶數': 1001, '男數': 1599, '
# ...

# %%
temp=Data.get("result")

# %%
temp
#暫時文件夾
# Out:
# [{'編號': 1,
#   '村別數': '東門里',
#   '鄰數': 31,
#   '戶數': 1700,
#   '男數': 2750,
#   '女數': 2799,
#   '總人口數': 5549,
#   '出生人數': 6,
#   '死亡人數': 2,
#   '結婚對數': 1,
#   '離婚對數': 0,
#   '遷入人數': 7,
#   '遷出人數': 24},
#  {'編號': 2,
#   '村別數': '西門里',
#   '鄰數': 42,
#   '戶數': 3492,
#   '男數': 5469,
#   '女數': 5732,
#   '總人口數': 11201,
#   '出生人數': 8,
#   '死亡人數': 4,
#   '結婚對數': 3,
#   '離婚對數': 1,
#   '遷入人數': 23,
#   '遷出人數': 38},
#  {'編號': 3,
#   '村別數': '南門里',
#   '鄰數': 34,
#   '戶數': 1910,
#   '男數': 2983,
#   '女數': 3091,
#   '總人口數': 6074,
#   '出生人數': 4,
#   '死亡人數': 1,
#   '結婚對數': 2,
#   '離婚對數': 0,
#   '遷入人數': 17,
#   '遷出人數': 20},
#  {'編號': 4,
#   '村別數': '北門里',
#   '鄰數': 28,
#   '戶數': 1386,
#   '男數': 2308,
#   '女數': 2210,
#   '總人口數': 4518,
#   '出生人數': 2,
#   '死亡人數': 2,
#   '結婚對數': 0,
#   '離婚對數': 0,
#   '遷入人數': 15,
#   '遷出人數': 26},
#  {'編號': 5,
#   '村別數': '古城里',
#   '鄰數': 25,
#   '戶數': 1396,
#   '男數': 2267,
#   '女數': 2249,
#   '總人口數': 4516,
#   '出生人數': 3,
#   '死亡人數': 1,
#   '結婚對數': 1,
#   '離婚對數': 0,
# ...

# %%
ask='東門里'

# %%
for j in temp:
    if ask==j.get('村別數'):
        print('村別數',ask,'鄰數','戶數','男數','女數','總人口數','出生人數','死亡人數','結婚對數','離婚對數','遷入人數',j.get('遷出人數'))

# %%
ask=1

# %%
for i in temp:
    if ask==i.get('出生人數'):
                print('村別數','鄰數','戶數','男數','女數','總人口數',ask,i.get('死亡人數'),'結婚對數','離婚對數','遷入人數','遷出人數')
# Out:
# 村別數 鄰數 戶數 男數 女數 總人口數 1 3 結婚對數 離婚對數 遷入人數 遷出人數
# 村別數 鄰數 戶數 男數 女數 總人口數 1 2 結婚對數 離婚對數 遷入人數 遷出人數
# 村別數 鄰數 戶數 男數 女數 總人口數 1 3 結婚對數 離婚對數 遷入人數 遷出人數
# 村別數 鄰數 戶數 男數 女數 總人口數 1 0 結婚對數 離婚對數 遷入人數 遷出人數
# 村別數 鄰數 戶數 男數 女數 總人口數 1 0 結婚對數 離婚對數 遷入人數 遷出人數
# 村別數 鄰數 戶數 男數 女數 總人口數 1 0 結婚對數 離婚對數 遷入人數 遷出人數
# 村別數 鄰數 戶數 男數 女數 總人口數 1 0 結婚對數 離婚對數 遷入人數 遷出人數
# 村別數 鄰數 戶數 男數 女數 總人口數 1 2 結婚對數 離婚對數 遷入人數 遷出人數
# 村別數 鄰數 戶數 男數 女數 總人口數 1 1 結婚對數 離婚對數 遷入人數 遷出人數

# %%
ask=17

# %%
for k in temp:
    if ask==k.get('編號'):
        print('村別數',ask,'鄰數','戶數','男數','女數','總人口數','出生人數','死亡人數','結婚對數','離婚對數','遷入人數',j.get('遷出人數'))
